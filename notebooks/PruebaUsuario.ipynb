# %%
from dotenv import load_dotenv
import os
 
load_dotenv()
 
print("AWS_ACCESS_KEY_ID:", os.getenv("AWS_ACCESS_KEY_ID"))
print("SUPABASE_URL:", os.getenv("SUPABASE_URL"))
# Out:
# AWS_ACCESS_KEY_ID: AKIA3RW2OJRGXD7ORGOT
# SUPABASE_URL: https://deeezkbuwjwdwiozbhzs.supabase.co

# %%
import boto3
 
s3 = boto3.client("s3")
resp = s3.list_buckets()
resp
# Out:
# {'ResponseMetadata': {'RequestId': 'Q20A2KEXH1SAFFA7',
#   'HostId': '+V5GU/787zx0nSlCTq+JhofLHLhgrC3wy02yQ0S/INxG+xpTSZG9uMoaZBkpcjl/lNFAaRtjhW4=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '+V5GU/787zx0nSlCTq+JhofLHLhgrC3wy02yQ0S/INxG+xpTSZG9uMoaZBkpcjl/lNFAaRtjhW4=',
#    'x-amz-request-id': 'Q20A2KEXH1SAFFA7',
#    'date': 'Sun, 30 Nov 2025 04:43:50 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'proyecto5c-datos',
#    'CreationDate': datetime.datetime(2025, 11, 25, 3, 6, 56, tzinfo=tzutc()),
#    'BucketArn': 'arn:aws:s3:::proyecto5c-datos'}],
#  'Owner': {'ID': 'b5f431fad2e569275c213ca04d8c4261ff639ab2f5373098633ba55cf8951054'}}

# %%
pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.41.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<1.42.0,>=1.41.5 (from boto3)
#   Downloading botocore-1.41.5-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\usuario\anaconda3\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.16.0,>=0.15.0 (from boto3)
#   Downloading s3transfer-0.15.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\usuario\anaconda3\lib\site-packages (from botocore<1.42.0,>=1.41.5->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\usuario\anaconda3\lib\site-packages (from botocore<1.42.0,>=1.41.5->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.5->boto3) (1.17.0)
# Downloading boto3-1.41.5-py3-none-any.whl (139 kB)
# Downloading botocore-1.41.5-py3-none-any.whl (14.3 MB)
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/14.3 MB 9.6 MB/s eta 0:00:02
#    --------------- ------------------------ 5.5/14.3 MB 16.6 MB/s eta 0:00:01
#    ------------------------ --------------- 8.7/14.3 MB 15.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.4/14.3 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.3/14.3 MB 16.3 MB/s eta 0:00:00
# Downloading s3transfer-0.15.0-py3-none-any.whl (85 kB)
# Installing collected packages: botocore, s3transfer, boto3
#
#   Attempting uninstall: botocore
#
#     Found existing installation: botocore 1.36.3
#
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#     Uninstalling botocore-1.36.3:
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#       Successfully uninstalled botocore-1.36.3
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    -------------------------- ------------- 2/3 [boto3]
#    ---------------------------------------- 3/3 [boto3]
#
# Successfully installed boto3-1.41.5 botocore-1.41.5 s3transfer-0.15.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.19.0 requires botocore<1.36.4,>=1.36.0, but you have botocore 1.41.5 which is incompatible.

# %%
from supabase import create_client
 
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")
 
supabase = create_client(url, key)
print("Cliente Supabase listo:", supabase is not None)
# Out:
# Cliente Supabase listo: True

# %%
pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.24.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.24.0 (from supabase)
#   Downloading realtime-2.24.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.24.0 (from supabase)
#   Downloading supabase_functions-2.24.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.24.0 (from supabase)
#   Downloading storage3-2.24.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.24.0 (from supabase)
#   Downloading supabase_auth-2.24.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.24.0 (from supabase)
#   Downloading postgrest-2.24.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\usuario\anaconda3\lib\site-packages (from supabase) (0.28.1)
# Collecting deprecation>=2.1.0 (from postgrest==2.24.0->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\usuario\anaconda3\lib\site-packages (from postgrest==2.24.0->supabase) (2.10.3)
# Collecting yarl>=1.20.1 (from postgrest==2.24.0->supabase)
#   Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Collecting pydantic<3.0,>=1.9 (from postgrest==2.24.0->supabase)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions>=4.14.0 (from realtime==2.24.0->supabase)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websockets<16,>=11 (from realtime==2.24.0->supabase)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\usuario\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.24.0->supabase) (2.10.1)
# Collecting strenum>=0.4.15 (from supabase-functions==2.24.0->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in c:\users\usuario\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.7.0)
# Requirement already satisfied: certifi in c:\users\usuario\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\usuario\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\usuario\anaconda3\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\usuario\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->postgrest==2.24.0->supabase)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.24.0->supabase)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.24.0->supabase)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usuario\anaconda3\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.24.0->supabase) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0,>=1.9->postgrest==2.24.0->supabase)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0,>=1.9->postgrest==2.24.0->supabase)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in c:\users\usuario\anaconda3\lib\site-packages (from deprecation>=2.1.0->postgrest==2.24.0->supabase) (24.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.24.0->supabase) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\usuario\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.24.0->supabase) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\usuario\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.24.0->supabase) (2.21)
# Requirement already satisfied: multidict>=4.0 in c:\users\usuario\anaconda3\lib\site-packages (from yarl>=1.20.1->postgrest==2.24.0->supabase) (6.1.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\usuario\anaconda3\lib\site-packages (from yarl>=1.20.1->postgrest==2.24.0->supabase) (0.3.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\usuario\anaconda3\lib\site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.0)
# Downloading supabase-2.24.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.24.0-py3-none-any.whl (21 kB)
# Downloading realtime-2.24.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.24.0-py3-none-any.whl (19 kB)
# Downloading supabase_auth-2.24.0-py3-none-any.whl (48 kB)
# Downloading supabase_functions-2.24.0-py3-none-any.whl (8.5 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 13.5 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Installing collected packages: strenum, yarl, websockets, typing-extensions, hyperframe, hpack, deprecation, typing-inspection, pydantic-core, h2, pydantic, supabase-functions, supabase-auth, storage3, realtime, postgrest, supabase
#
#   Attempting uninstall: yarl
#
#     Found existing installation: yarl 1.18.0
#
#     Uninstalling yarl-1.18.0:
#
#       Successfully uninstalled yarl-1.18.0
#
#    ---- -----------------------------------  2/17 [websockets]
#   Attempting uninstall: typing-extensions
#    ---- -----------------------------------  2/17 [websockets]
#     Found existing installation: typing_extensions 4.12.2
#    ---- -----------------------------------  2/17 [websockets]
#     Uninstalling typing_extensions-4.12.2:
#    ---- -----------------------------------  2/17 [websockets]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#    ------- --------------------------------  3/17 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ------- --------------------------------  3/17 [typing-extensions]
#    --------- ------------------------------  4/17 [hyperframe]
#   Attempting uninstall: pydantic-core
#    --------- ------------------------------  4/17 [hyperframe]
#     Found existing installation: pydantic_core 2.27.1
#    --------- ------------------------------  4/17 [hyperframe]
#     Uninstalling pydantic_core-2.27.1:
#    --------- ------------------------------  4/17 [hyperframe]
#       Successfully uninstalled pydantic_core-2.27.1
#    --------- ------------------------------  4/17 [hyperframe]
#    --------------------- ------------------  9/17 [h2]
#   Attempting uninstall: pydantic
#    --------------------- ------------------  9/17 [h2]
#     Found existing installation: pydantic 2.10.3
#    --------------------- ------------------  9/17 [h2]
#     Uninstalling pydantic-2.10.3:
#    --------------------- ------------------  9/17 [h2]
#       Successfully uninstalled pydantic-2.10.3
#    --------------------- ------------------  9/17 [h2]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ----------------------- ---------------- 10/17 [pydantic]
#    ----------------------- ---------------- 10/17 [pydantic]
#    -------------------------------- ------- 14/17 [realtime]
#    ---------------------------------------- 17/17 [supabase]
#
# Successfully installed deprecation-2.1.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 postgrest-2.24.0 pydantic-2.12.5 pydantic-core-2.41.5 realtime-2.24.0 storage3-2.24.0 strenum-0.4.15 supabase-2.24.0 supabase-auth-2.24.0 supabase-functions-2.24.0 typing-extensions-4.15.0 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.
